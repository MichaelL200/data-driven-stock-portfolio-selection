# %%
# TODO: Write summary section (Issue #35)
#   Include:
#   - observations
#   - limitations
#   - conclusions
#   - project details and personal reflections

# %% [markdown]
# # Podsumowanie
#
# W trakcie pracy nad projektem udało się ukończyć 2 główne etapy - tworzenie zbioru danych i tworzenie strategii. Z czego ten pierwszy jest okazał się znacznie większy ze względu na swoją złożoność, ale jednocześnie kluczowy, gdyż bez dobrego zbioru danych wyniki strategii byłyby mało reprezentatywne. Jego trudność polegała na tym, że żadne źródło danych nie gwarantowało 100-procentowego pokrycia, a w przypadku EODHD zwiększanie pokrycia dla brakujących tickerów polegała na sprawdzaniu historii spółek i ręcznym mapowaniu ich tickerów. Pomimo faktu, że celem nie było pokonanie Benchmarku (o Sharpe ≈ 0,56) to udało się to zrobić w przypadku 2 utworzonych strategii:
#
# 1. Strategii największych współczynnikiów Sharpe'a przy doborze rocznym (o Sharpe ≈ 0,65)
# 2. Strategii Monte Carlo na portfelach przy doborze kwartalnym (o Sharpe ≈ 0,63)
#
# Rezultaty te jednak nie gwarantują, że te strategie przynosiłyby lepsze zyski niż inwestowanie w szeroki indeks akcji - np. w indeks S&P 500 z 3 powodów:
#
# 1. Najbardziej fundamentalny dotyczy jakości danych. Dane pobrane z obydwu serwisów nie mają 100-procentowego pokrycia, co wprowadza błąd wyprzedzania, a próba jego zniwelowania również obarczona jest niepewnością. Dodatkowo w utworzonym zbiorze danych pojawiają się inne błędy spowodowane sklejeniem szeregów czasowych z 2 źródeł, nieuwzględnieniem splitów czy scaleń lub zwyczajnie poszatkowanym pokryciem w danych. W przypadku astronomicznych dziennych skoków cenowych, w górę czy w dół, będących oczywistymi błędami w danych, ich wyniki nie były brane pod uwagę przy testowaniu zwrotów portfolio.
# 2. Nawet przy założeniu braku wpływu poprzedniego czynnika, zwroty strategii z przeszłości nie gwarantują, że w przyszłości bedą performować podobnie. Przeszłe wyniki nie sa gwarancją przyszłych wyników, a rynek podlega ciągłym zmianom.
