# %%
# TODO: Write summary section (Issue #35)
#   Include:
#   - observations
#   - limitations
#   - conclusions
#   - project details and personal reflections

# %% [markdown]
# # Podsumowanie
#
# Wynikiem projektu są 2 strategie oparte na Monte Carlo
