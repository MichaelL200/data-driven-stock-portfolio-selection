# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) return false;

# %%
import dataset, plots
import pandas as pd

sp500_components = dataset.SP500.load_historical()

# %% [markdown]
# ### Dane cenowe z EODHD
#
# Na EODHD dostępnych jest kilka tickerów, dla których można korzystać z danych bezpłatnie. W przypadku akcji amerykańskich są to:
# - AAPL.US
# - TSLA.US
# - VTI.US
# - AMZN.US

# %%
demo_key = "demo"
free_tickers = ["AAPL", "TSLA", "VTI", "AMZN"]

dataset.EODHD.download(
    tickers=free_tickers,
    api_key=demo_key,
)
# Out:
# Number of unique tickers extracted: 4
# Downloading full history for 4 tickers.
# Downloading 4 tickers...
# Saved Close.csv (16223 rows x 1156 columns)
# Saved Open.csv (16223 rows x 1156 columns)
# Saved High.csv (16223 rows x 1156 columns)
# Saved Low.csv (16223 rows x 1156 columns)
# Saved Volume.csv (16223 rows x 1156 columns)
# Saved Adj_Close.csv (16223 rows x 1156 columns)

# %%
eodhd_loaded = dataset.EODHD.load()

# %% [markdown]
# Aby pobrać dane o spółkach wycofanych z giełdy trzeba zmapować tickery z submodułu sp500, na te, które istnieją na liście wycofanych tickerów w EODHD.

# %%
delisted_tickers: pd.DataFrame = dataset.EODHD.get_delisted_tickers()

plots.summarize_df(delisted_tickers)
# Out:
# DataFrame summary:
# <class 'pandas.DataFrame'>
# RangeIndex: 57347 entries, 0 to 57346
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Code      57347 non-null  str
#  1   Name      57347 non-null  str
#  2   Country   57346 non-null  str
#  3   Exchange  57347 non-null  str
#  4   Currency  57347 non-null  str
#  5   Type      57346 non-null  str
#  6   Isin      17526 non-null  str
# dtypes: str(7)
# memory usage: 3.1 MB
# None
#               Code            Name Country Exchange Currency          Type  \
# count        57347           57347   57346    57347    57347         57346
# unique       57347           52999       2       15        4            10
# top     0P0000V6X4  Public Storage     USA    NMFQS      USD  Common Stock
# freq             1              23   57345    21274    57343         31556
#
#                 Isin
# count          17526
# unique         17063
# top     KYG8089R1267
# freq               4
#              Code                                               Name Country  \
# 0      0P0000V6X4             Vanguard Target Retire Trust Plus 2040     USA
# 1      0P0001UM32           Life Cycle Global Select UCITS X USD Acc     USA
# 57345         ZZZ  Cyber Hornet S&P 500 and Bitcoin 75/25 Strateg...     USA
# 57346       ZZZOD                             Zinc One Resources Inc     USA
#
#         Exchange Currency          Type          Isin
# 0           NYSE      USD          FUND           NaN
# 1           PINK      USD          FUND           NaN
# 57345  NYSE ARCA      USD           ETF  US45407J4094
# 57346       PINK      USD  Common Stock           NaN

# %%
# ///////// TESTING MAPPING OF TICKERS TO API SYMBOLS /////// #
 
# import os, eodhd, plots, pandas as pd

# api_key: str = os.getenv("EODHD_API_KEY")
# client: eodhd.APIClient = eodhd.APIClient(api_key=api_key)
# api_symbol: str = "TMC-A"
# kwargs: dict = {"symbol": api_symbol, "period": "d", "order": "a"}
# raw_data: list = client.get_eod_historical_stock_market_data(**kwargs)
# frame: pd.DataFrame = pd.DataFrame(raw_data)
# plots.summarize_df(frame)

# ////////////////////////////////////////////////////////// #

# %%
tickers = dataset.SP500.extract_tickers(sp500_components)

dataset.EODHD.download(tickers)
# Out:
# Number of unique tickers extracted: 1194
# Number of unique tickers extracted: 1194
# Downloading full history for 1194 tickers.
# Downloading 1194 tickers...
# No valid data returned for AAMRQ.US
# No valid data returned for ABKFQ.US
# [09:25:10] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/AFS.A.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&ord
#            er=a
# No valid data returned for AFS.A.US
# [09:27:02] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/ATGE.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&orde
#            r=a
# No valid data returned for ATGE.US
# [09:27:30] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/AZA.A.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&ord
#            er=a
# No valid data returned for AZA.A.US
# [09:27:43] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/BAY.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for BAY.US
# No valid data returned for BHMSQ.US
# [09:29:00] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/BLY.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for BLY.US
# [09:29:25] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/BRK.B.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&ord
#            er=a
# No valid data returned for BRK.B.US
# No valid data returned for CDAY.US
# [09:32:05] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/CIT.A.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&ord
#            er=a
# No valid data returned for CIT.A.US
# [09:32:21] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/CMB.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for CMB.US
# [09:35:05] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/CYR.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for CYR.US
# [09:37:47] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/DWD.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for DWD.US
# [09:40:43] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/FBO.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for FBO.US
# [09:43:39] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/GFS.A.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&ord
#            er=a
# No valid data returned for GFS.A.US
# [09:43:48] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/GIDL.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&orde
#            r=a
# No valid data returned for GIDL.US
# No valid data returned for GWF.US
# [09:45:40] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/HFS.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for HFS.US
# [09:49:56] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/LDW.B.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&ord
#            er=a
# No valid data returned for LDW.B.US
# No valid data returned for LEHMQ.US
# [09:50:22] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/LLX.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for LLX.US
# No valid data returned for LOR.US
# No valid data returned for MTLQQ.US
# [09:54:22] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/NAE.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for NAE.US
# No valid data returned for NLV.US
# [09:55:21] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/NMK.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for NMK.US
# [09:56:07] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/NYN.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for NYN.US
# [09:57:43] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/PEL.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for PEL.US
# No valid data returned for RE.US
# No valid data returned for RSHCQ.US
# [10:02:44] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/SGP_old.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&o
#            rder=a
# No valid data returned for SGP_old.US
# [10:02:48] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/SHN.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for SHN.US
# [10:05:42] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/TDM.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for TDM.US
# [10:06:51] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/TMC.A.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&ord
#            er=a
# No valid data returned for TMC.A.US
# No valid data returned for UAWGQ.US
# [10:09:32] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/USH.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&order
#            =a
# No valid data returned for USH.US
# [10:09:33] Expecting value: line 1 column 1 (char 0)                                                  BaseAPI.py:39
#            404 Client Error: Not Found for url:                                                       BaseAPI.py:52
#            https://eodhd.com/api/eod/USHC.US?api_token=69b00122c69c14.83606105&fmt=json&period=d&orde
#            r=a
# No valid data returned for USHC.US
# No valid data returned for VAT.US
# No valid data returned for WCOEQ.US
# Saved Close.csv (16223 rows x 1156 columns)
# Saved Open.csv (16223 rows x 1156 columns)
# Saved High.csv (16223 rows x 1156 columns)
# Saved Low.csv (16223 rows x 1156 columns)
# Saved Volume.csv (16223 rows x 1156 columns)
# Saved Adj_Close.csv (16223 rows x 1156 columns)

# %%
eodhd_data: dict[str, pd.DataFrame] = dataset.EODHD.load()

# %%
coverage_df = plots.coverage_over_time(
    price_data=eodhd_data,
    components=sp500_components,
    filename="19-eodhd-coverage-over-time.png"
)

plots.summarize_df(coverage_df)
# Out:
# Missing ticker coverage periods:
# - AAL:
#   missing from 1996-01-02 to 1997-01-13
# - AAMRQ:
#   not downloaded from 1996-01-02 to 2003-03-10
# - ABI:
#   missing from 1996-01-02 to 1997-12-29
#   missing from 2008-11-18 to 2008-11-20
# - ABKFQ:
#   not downloaded from 2000-12-11 to 2008-06-10
# - ABS:
#   missing from 1996-01-02 to 1997-12-29
# - ABX:
#   missing from 1996-01-02 to 2002-07-18
# - ACKH:
#   missing from 1996-01-02 to 1997-12-29
# - ACV:
#   missing from 1996-01-02 to 2006-11-16
# - ADCT:
#   missing from 1999-08-02 to 2003-09-08
#   missing from 2005-05-13 to 2005-06-06
# - AET:
#   missing from 1996-01-02 to 1997-12-29
# - AFS.A:
#   not downloaded from 1998-04-08 to 2000-11-29
# - AGC:
#   missing from 1996-01-02 to 2001-03-22
# - AHM:
#   missing from 1996-01-02 to 1997-12-29
# - AL:
#   missing from 1996-01-02 to 2002-07-18
# - AM:
#   missing from 1996-01-02 to 1997-12-29
# - AMH:
#   missing from 1996-01-02 to 1997-09-08
# - AMP:
#   missing from 1996-01-02 to 1999-03-30
# - ANDW:
#   missing from 1996-01-02 to 1997-12-29
# - ANRZQ:
#   missing from 2011-06-02 to 2012-10-01
# - ANV:
#   missing from 1996-01-02 to 1999-04-08
# - APC:
#   missing from 1997-07-28 to 1997-12-29
# - AR:
#   missing from 1996-01-02 to 1999-10-26
# - ARC:
#   missing from 1996-01-02 to 1997-12-29
# - ARNC:
#   missing from 1996-01-02 to 2016-10-31
# - AS:
#   missing from 1996-01-02 to 1998-11-23
# - ASC:
#   missing from 1996-01-02 to 1999-06-23
# - ASND:
#   missing from 1998-06-12 to 1999-06-24
# - AT:
#   missing from 1996-01-02 to 2003-09-08
# - ATGE:
#   not downloaded from 2009-06-09 to 2012-09-25
# - AVP:
#   missing from 1996-01-02 to 1997-12-29
# - AZA.A:
#   not downloaded from 1996-01-02 to 2001-06-20
# - BAY:
#   not downloaded from 1996-02-12 to 1998-08-28
# - BBBY:
#   missing from 1999-10-01 to 2002-05-29
# - BBT:
#   missing from 1997-12-04 to 2000-06-27
#   missing on 2001-12-05
# - BCR:
#   missing from 1996-01-02 to 1997-12-29
# - BDK:
#   missing from 1996-01-02 to 1997-12-29
# - BEAM:
#   missing from 1996-01-02 to 2011-10-03
# - BEV:
#   missing from 1996-01-02 to 1997-12-02
# - BF.B:
#   missing from 1996-01-11 to 1996-01-12
#   missing on 1996-05-09
#   missing on 1996-05-23
#   missing on 1996-06-28
#   missing on 1996-07-18
#   missing on 1996-07-22
#   missing on 1996-07-31
#   missing on 1996-08-28
#   missing on 1996-12-24
#   missing on 1997-04-09
#   missing on 1997-07-08
#   missing from 1998-11-20 to 1998-11-24
#   missing on 1999-10-13
#   missing on 2000-06-23
#   missing on 2007-07-24
# - BFI:
#   missing from 1996-01-02 to 1999-07-30
# - BFO:
#   missing from 1996-01-02 to 2000-10-02
# - BHGE:
#   missing from 1996-01-02 to 2017-06-26
# - BHMSQ:
#   not downloaded from 1996-01-02 to 2000-12-08
# - BKB:
#   missing from 1996-01-02 to 1997-12-29
# - BLS:
#   missing from 1996-01-02 to 1997-12-29
# - BLY:
#   not downloaded from 1996-01-02 to 1996-12-18
# - BMET:
#   missing from 1996-01-02 to 1997-12-29
# - BMGCA:
#   missing from 1996-07-22 to 1997-12-29
# - BMS:
#   missing from 1996-01-02 to 1997-12-29
# - BNI:
#   missing from 1996-01-02 to 1997-12-29
# - BNL:
#   missing from 1996-01-02 to 1998-06-30
# - BOAT:
#   missing from 1996-01-02 to 1997-01-03
# - BOL:
#   missing from 1996-01-02 to 1997-12-29
# - BR:
#   missing from 1996-01-02 to 2006-03-30
# - BRK.B:
#   not downloaded from 2010-02-16 to 2026-01-14
# - BSC:
#   missing from 1998-07-01 to 1998-12-31
# - BT:
#   missing from 1996-01-02 to 1996-01-10
#   missing on 1996-01-22
#   missing on 1996-01-24
#   missing on 1996-01-31
#   missing on 1996-02-12
#   missing from 1996-02-20 to 1996-02-21
#   missing on 1996-03-13
#   missing from 1996-03-15 to 1996-03-25
#   missing from 1996-04-03 to 1996-04-24
#   missing from 1996-05-03 to 1996-05-10
#   missing on 1996-05-30
#   missing on 1996-06-05
#   missing on 1996-06-26
#   missing from 1996-07-11 to 1996-08-16
#   missing on 1996-08-26
#   missing on 1996-09-09
#   missing from 1996-09-17 to 1996-09-18
#   missing on 1996-09-20
#   missing from 1996-10-18 to 1996-10-24
#   missing on 1996-11-07
#   missing from 1996-12-03 to 1996-12-05
#   missing on 1996-12-18
#   missing from 1996-12-27 to 1997-01-07
#   missing on 1997-01-20
#   missing on 1997-02-06
#   missing on 1997-04-02
#   missing from 1997-04-08 to 1997-04-09
#   missing on 1997-04-28
#   missing on 1997-05-07
#   missing on 1997-05-15
#   missing on 1997-05-30
#   missing on 1997-06-19
#   missing on 1997-07-03
#   missing on 1997-07-17
#   missing on 1997-07-25
#   missing on 1997-08-13
#   missing from 1997-09-05 to 1997-09-08
#   missing on 1997-10-24
#   missing on 1997-10-30
#   missing on 1997-11-03
#   missing on 1997-11-21
#   missing on 1997-12-01
#   missing on 1997-12-05
#   missing on 1997-12-29
#   missing from 1998-01-02 to 1998-01-05
#   missing on 1998-01-15
#   missing on 1998-01-22
#   missing from 1998-01-26 to 1998-01-30
#   missing on 1998-02-26
#   missing from 1998-04-01 to 1998-04-09
#   missing on 1998-04-15
#   missing on 1998-04-28
#   missing on 1998-05-18
#   missing on 1998-05-27
#   missing on 1998-07-07
#   missing on 1998-08-13
#   missing on 1998-12-24
#   missing from 1999-01-04 to 1999-01-14
#   missing from 1999-01-22 to 1999-01-26
#   missing on 1999-03-18
#   missing on 1999-03-29
#   missing on 1999-05-04
#   missing on 1999-05-17
#   missing on 1999-05-19
# - BUD:
#   missing from 1996-01-02 to 1997-12-29
# - CA:
#   missing from 1996-01-02 to 1997-12-29
# - CBH:
#   missing from 2006-06-06 to 2008-03-18
# - CCB:
#   missing from 1996-01-02 to 1996-02-01
# - CCE:
#   missing from 1998-10-08 to 1998-11-05
#   missing from 1998-11-16 to 1998-12-24
# - CCI:
#   missing from 1996-01-02 to 1998-08-17
# - CCTYQ:
#   missing from 1996-01-02 to 1997-12-29
# - CDAY:
#   not downloaded from 2021-09-20 to 2023-10-18
# - CEG:
#   missing from 1996-01-02 to 1997-12-29
# - CEN:
#   missing from 1996-01-02 to 1997-12-29
# - CF:
#   missing from 2000-06-19 to 2004-08-26
# - CFC:
#   missing from 1997-06-18 to 1998-12-31
# - CFL:
#   missing from 1996-01-02 to 1998-04-27
# - CG:
#   missing from 1996-01-02 to 2000-10-30
# - CGP:
#   missing from 1996-01-02 to 1997-12-29
# - CHA:
#   missing from 1996-01-02 to 2000-06-16
# - CHRS:
#   missing from 1996-01-02 to 1998-04-07
# - CIT.A:
#   not downloaded from 2000-07-17 to 2001-05-31
# - CMB:
#   not downloaded from 1996-01-02 to 1996-03-29
# - CNC:
#   missing from 1997-01-15 to 2001-12-06
# - CNG:
#   missing from 1996-01-02 to 2000-01-28
# - CNW:
#   missing from 1996-01-02 to 1996-11-27
# - COMS:
#   missing from 1996-01-02 to 2000-07-27
# - COV:
#   missing from 1996-01-02 to 1996-08-08
#   missing from 2012-06-21 to 2015-01-15
# - CPQ:
#   missing from 1996-01-02 to 1998-12-31
# - CPWR:
#   missing from 1999-01-04 to 2003-09-08
# - CR:
#   missing from 1996-01-02 to 2003-09-08
# - CRR:
#   missing from 1996-01-02 to 1997-05-19
# - CSE:
#   missing from 1996-01-22 to 1999-11-12
# - CSR:
#   missing from 1996-01-02 to 1997-10-14
#   missing from 1997-11-28 to 1997-12-01
#   missing on 1997-12-24
#   missing on 1998-01-12
#   missing on 1998-01-15
#   missing on 1998-01-29
#   missing on 1998-02-13
#   missing from 1998-03-04 to 1998-03-05
#   missing on 1998-05-22
#   missing on 1998-05-27
#   missing on 1998-06-08
#   missing on 1998-06-26
#   missing on 1998-07-01
#   missing on 1998-08-12
#   missing from 1998-08-26 to 1998-08-28
#   missing on 1998-09-17
#   missing on 1998-09-22
#   missing on 1998-09-29
#   missing on 1998-10-05
#   missing on 1998-10-14
#   missing on 1998-11-05
#   missing on 1998-12-31
#   missing on 1999-04-06
#   missing on 1999-04-14
#   missing on 1999-06-04
#   missing on 1999-08-09
#   missing on 1999-09-20
#   missing on 1999-10-14
#   missing on 1999-10-28
#   missing on 1999-11-16
#   missing on 2000-02-28
#   missing on 2000-05-04
#   missing on 2000-06-01
# - CTX:
#   missing from 1996-01-02 to 1997-12-29
# - CTXS:
#   missing from 1999-12-01 to 2003-09-30
# - CYM:
#   missing from 1996-01-02 to 1997-12-29
# - CYR:
#   not downloaded from 1996-01-02 to 1996-03-25
# - DALRQ:
#   missing from 1996-01-02 to 1997-12-29
# - DCNAQ:
#   missing from 1996-01-02 to 1998-12-31
# - DEC:
#   missing from 1996-01-02 to 1998-06-08
# - DELL:
#   missing from 1996-09-06 to 1997-12-29
# - DGN:
#   missing from 1996-01-02 to 1999-10-12
# - DI:
#   missing from 1996-01-02 to 1998-09-29
# - DIGI:
#   missing from 1996-01-02 to 1997-11-28
#   missing from 1997-12-02 to 1997-12-31
#   missing from 1998-01-05 to 1998-01-21
#   missing from 1998-01-23 to 1998-01-26
#   missing from 1998-01-29 to 1998-04-30
#   missing on 1998-05-18
#   missing on 1998-07-01
#   missing on 1998-07-06
#   missing from 1998-07-20 to 1998-07-21
#   missing from 1998-08-06 to 1998-08-17
# - DJ:
#   missing from 1996-01-02 to 1997-12-29
# - DO:
#   missing from 2014-08-05 to 2014-08-08
# - DOW:
#   missing from 1996-01-02 to 2003-09-08
# - DWD:
#   not downloaded from 1996-01-02 to 1997-05-30
# - DYN:
#   missing from 2000-10-03 to 2003-09-30
# - EC:
#   missing from 1996-01-02 to 1997-12-29
# - ECH:
#   missing from 1996-01-02 to 1998-07-09
# - ECO:
#   missing from 1996-01-02 to 1998-01-15
# - EFU:
#   missing from 1996-01-02 to 2000-10-30
# - EKDKQ:
#   missing from 1996-01-02 to 1997-12-29
# - EMC:
#   missing from 1996-03-28 to 2003-09-08
# - ENRNQ:
#   missing from 1996-01-02 to 1997-12-29
# - ENS:
#   missing from 1996-01-02 to 1997-08-05
# - EP:
#   missing on 1999-10-26
# - EQ:
#   missing from 2006-05-18 to 2009-06-30
# - ETS:
#   missing from 1996-01-02 to 2001-08-03
# - FBF:
#   missing from 1996-01-02 to 1997-12-29
# - FBO:
#   not downloaded from 1996-01-02 to 1996-03-12
# - FCN:
#   missing from 1996-01-02 to 1996-05-03
# - FDC:
#   missing from 1996-01-02 to 1997-12-29
# - FG:
#   missing from 1996-01-02 to 1998-04-16
# - FJ:
#   missing from 1996-01-02 to 1997-12-29
# - FLMIQ:
#   missing from 1996-01-02 to 1997-12-19
# - FLTWQ:
#   missing from 1996-01-02 to 1997-12-29
# - FMY:
#   missing from 1998-07-10 to 1999-05-19
# - FOXA:
#   missing from 2004-12-20 to 2019-02-27
# - FRO:
#   missing from 1997-01-02 to 1999-09-21
# - FSL:
#   missing from 2004-12-03 to 2006-12-01
# - FTL.A:
#   missing from 1996-01-02 to 1997-12-29
# - FTR:
#   missing on 2004-03-15
# - FWLT:
#   missing from 1996-01-02 to 1997-12-29
# - G:
#   missing from 1996-01-02 to 1997-12-29
# - GAPTQ:
#   missing from 1996-01-02 to 1998-12-31
# - GAS:
#   missing from 1996-01-02 to 1997-12-29
# - GDT:
#   missing from 1996-12-19 to 1997-12-29
# - GDW:
#   missing from 1996-01-02 to 1997-12-29
# - GFS.A:
#   not downloaded from 1996-01-02 to 1998-07-13
# - GIDL:
#   not downloaded from 1996-01-02 to 1997-07-09
# - GLD:
#   missing from 1996-01-02 to 1997-04-29
# - GLK:
#   missing from 1996-01-02 to 1997-12-29
# - GNT:
#   missing from 1996-03-13 to 1997-12-29
# - GP:
#   missing from 1996-01-02 to 2005-12-16
# - GPU:
#   missing from 1996-01-02 to 1997-12-29
# - GR:
#   missing from 1996-01-02 to 1997-12-29
# - GRN:
#   missing from 1996-01-02 to 1998-12-14
# - GSX:
#   missing from 1996-01-02 to 1998-10-06
# - GTE:
#   missing from 1996-01-02 to 2000-06-29
# - GWF:
#   not downloaded from 1996-01-02 to 1997-06-26
# - HBOC:
#   missing from 1997-10-23 to 1997-12-29
# - HCA:
#   missing from 1996-01-02 to 1997-12-29
# - HCR:
#   missing from 1998-09-28 to 2003-09-08
# - HDLM:
#   missing from 1996-01-02 to 1996-03-05
# - HET:
#   missing from 1996-01-02 to 1997-12-29
#   missing from 2007-12-31 to 2008-01-24
# - HFS:
#   not downloaded from 1996-08-16 to 1997-12-12
# - HI:
#   missing from 1996-01-02 to 1997-12-29
# - HLT:
#   missing from 1996-01-02 to 1997-12-29
# - HM:
#   missing from 1996-01-02 to 1997-12-29
# - HNZ:
#   missing from 1996-01-02 to 2003-09-08
# - HPC:
#   missing from 1996-01-02 to 1997-12-29
# - HPH:
#   missing from 1996-01-02 to 1999-06-08
# - HRS:
#   missing from 1996-01-02 to 1999-11-05
# - HSH:
#   missing from 1996-01-02 to 2012-06-25
# - I:
#   missing from 1996-01-02 to 1996-03-29
# - IKN:
#   missing from 1996-01-02 to 1997-12-29
# - INCLF:
#   missing from 1996-01-02 to 1997-12-29
# - INGR:
#   missing from 1996-01-02 to 1997-07-25
# - JH:
#   missing from 1996-01-02 to 1998-03-30
# - JOS:
#   missing from 1996-01-02 to 1997-12-29
# - JP:
#   missing from 1996-01-02 to 2006-03-30
# - KATE:
#   missing from 1996-01-02 to 1997-12-29
# - KM:
#   missing from 1996-01-02 to 1997-12-29
# - KMG:
#   missing from 1996-01-02 to 1997-01-21
# - KRB:
#   missing from 1996-01-02 to 1997-12-29
# - KRI:
#   missing from 1996-01-02 to 1997-12-29
# - KWP:
#   missing from 1996-01-02 to 1997-12-29
# - LB:
#   missing from 1996-01-02 to 2003-09-08
#   missing from 2011-06-29 to 2021-07-21
# - LDG:
#   missing from 1996-01-02 to 1997-12-29
# - LDW.B:
#   not downloaded from 1996-01-02 to 1999-12-07
# - LEHMQ:
#   not downloaded from 1998-01-12 to 2008-09-16
# - LIFE:
#   missing from 2008-11-24 to 2014-01-22
# - LLX:
#   not downloaded from 1996-01-02 to 1997-10-14
# - LOR:
#   not downloaded from 1996-01-02 to 1996-04-22
# - LU:
#   missing from 1996-10-01 to 1997-12-29
# - MAY:
#   missing from 1996-01-02 to 1997-12-29
# - MCIC:
#   missing from 1996-01-02 to 1997-09-08
#   missing on 1997-09-16
# - MDR:
#   missing from 1996-01-02 to 2003-08-18
# - MEA:
#   missing from 1996-01-02 to 1997-12-29
# - MEE:
#   missing from 1996-01-02 to 1997-12-29
# - MEL:
#   missing from 1996-01-02 to 1997-12-29
# - MER:
#   missing from 1996-01-02 to 1997-12-29
# - MI:
#   missing from 2002-02-11 to 2011-07-05
# - MII:
#   missing from 1996-01-02 to 1997-12-29
# - MIL:
#   missing from 1996-01-02 to 1997-12-29
# - MIR:
#   missing from 1997-08-07 to 2000-05-30
#   missing from 2001-04-03 to 2003-07-16
# - MKG:
#   missing from 1996-01-02 to 1997-12-29
# - MMI:
#   missing from 2011-01-04 to 2012-05-15
# - MNR:
#   missing from 1996-01-02 to 1998-09-24
# - MOB:
#   missing from 1996-01-02 to 1999-11-30
# - MST:
#   missing from 1996-01-02 to 1998-08-13
# - MTL:
#   missing from 1998-02-23 to 1999-09-17
# - MTLQQ:
#   not downloaded from 1996-01-02 to 2009-05-29
# - MWI:
#   missing from 1996-01-02 to 1997-12-29
# - MWV:
#   missing from 1996-01-02 to 1997-12-29
# - MYG:
#   missing from 1996-01-02 to 2003-09-08
# - MZIAQ:
#   missing from 1996-01-02 to 1997-12-29
# - NAE:
#   not downloaded from 1996-01-02 to 1997-08-06
# - NCC:
#   missing from 1996-01-02 to 1997-12-29
# - NE:
#   missing from 2001-01-16 to 2009-03-20
#   missing from 2011-01-18 to 2015-07-15
# - NLC:
#   missing from 1996-01-02 to 1999-07-30
# - NLV:
#   not downloaded from 1996-04-01 to 2000-01-05
# - NMK:
#   not downloaded from 1996-01-02 to 2002-01-31
# - NOVL:
#   missing from 1996-01-02 to 1997-12-29
# - NRTLQ:
#   missing from 1996-01-02 to 1997-12-29
# - NSI:
#   missing from 1996-01-02 to 2001-11-30
# - NSM:
#   missing from 1996-01-02 to 1997-12-29
# - NVLS:
#   missing from 2000-06-19 to 2003-09-08
# - NYN:
#   not downloaded from 1996-01-02 to 1997-08-14
# - OAT:
#   missing from 1996-01-02 to 1997-12-29
# - OM:
#   missing from 1996-01-02 to 1996-09-30
# - ONE:
#   missing from 1996-01-02 to 1997-12-29
# - ORX:
#   missing from 1996-01-02 to 1997-12-29
# - OWENQ:
#   missing from 1996-01-02 to 1997-12-29
# - PAC:
#   missing from 1996-01-02 to 1997-03-19
# - PAS:
#   missing from 1996-01-02 to 1997-12-29
# - PBY:
#   missing from 1996-01-02 to 2000-03-29
# - PCS:
#   missing from 1998-11-24 to 2003-09-08
# - PD:
#   missing from 1996-01-02 to 1997-12-29
# - PDG:
#   missing from 1996-01-02 to 1997-12-29
# - PEAK:
#   missing from 2019-11-05 to 2024-02-01
# - PEL:
#   not downloaded from 1996-01-02 to 1997-06-18
# - PET:
#   missing from 1996-01-02 to 1998-06-26
# - PGL:
#   missing from 1996-01-02 to 1997-12-29
# - PGN:
#   missing from 1996-01-02 to 1997-12-29
# - PHA:
#   missing from 1996-01-02 to 1997-12-29
# - PHB:
#   missing from 1996-01-02 to 1999-10-01
# - PLL:
#   missing from 1996-01-02 to 1997-12-29
# - PMI:
#   missing from 1996-01-02 to 1996-05-30
# - PNU:
#   missing from 1996-01-02 to 1997-12-29
# - PPW:
#   missing from 1996-01-02 to 1997-12-29
# - PRD:
#   missing from 1996-01-02 to 1997-12-29
# - PVN:
#   missing from 1996-01-02 to 1998-12-31
# - PVT:
#   missing from 1998-08-31 to 1999-06-30
# - PWER:
#   missing from 2000-10-23 to 2005-03-09
# - PX:
#   missing from 1996-01-02 to 1997-12-29
# - PZE:
#   missing from 1996-01-02 to 1998-12-24
# - RAL:
#   missing from 1996-01-02 to 1997-12-29
# - RBD:
#   missing from 1996-01-02 to 1997-12-29
# - RBK:
#   missing from 1996-01-02 to 1997-12-29
# - RDC:
#   missing from 1996-01-02 to 1997-12-29
# - RE:
#   not downloaded from 2017-06-19 to 2023-06-20
# - RLM:
#   missing from 1996-01-02 to 2000-04-27
# - RML:
#   missing from 1996-01-02 to 1997-12-29
# - RNB:
#   missing from 1996-01-02 to 1997-12-29
# - ROH:
#   missing from 1996-01-02 to 1997-12-29
# - RSHCQ:
#   not downloaded from 1996-01-02 to 2011-06-30
# - RTN:
#   missing from 1996-01-02 to 1997-12-29
#   missing on 2020-04-03
# - RX:
#   missing from 1996-11-04 to 1997-12-29
# - RYAN:
#   missing from 1996-01-02 to 1996-12-27
# - RYC:
#   missing from 1996-01-02 to 1997-12-29
# - RYI:
#   missing from 1996-01-02 to 1998-06-30
# - S:
#   missing from 1996-01-02 to 1997-12-29
# - SAF:
#   missing from 1996-01-02 to 1997-12-29
# - SAI:
#   missing from 1997-07-17 to 1998-12-31
# - SB:
#   missing from 1996-01-02 to 1997-11-21
# - SDS:
#   missing from 2002-07-22 to 2005-08-11
# - SE:
#   missing from 2007-01-03 to 2017-02-24
# - SEG:
#   missing from 1996-08-16 to 2000-11-20
# - SFA:
#   missing from 1996-01-02 to 1997-12-29
# - SFS:
#   missing from 1996-01-02 to 1997-07-25
# - SGID:
#   missing from 1996-01-02 to 1997-12-29
# - SGP:
#   missing from 1996-01-02 to 2009-10-29
# - SHN:
#   not downloaded from 1996-01-02 to 1996-12-27
# - SIAL:
#   missing from 1996-01-02 to 1997-12-29
# - SK:
#   missing from 1996-01-02 to 1998-03-30
# - SMI:
#   missing from 1996-01-02 to 2000-12-11
# - SMS:
#   missing from 1996-01-02 to 1997-12-29
# - SNT:
#   missing on 1996-01-04
#   missing on 1996-04-03
#   missing on 1998-09-29
#   missing on 1998-10-01
#   missing on 1998-11-13
#   missing on 1999-06-24
# - SRR:
#   missing from 1996-01-02 to 1997-10-06
# - STI:
#   missing from 1996-01-02 to 1997-12-29
# - STJ:
#   missing from 1996-01-02 to 1997-12-29
# - STO:
#   missing from 1996-01-02 to 1997-12-29
# - STR:
#   missing from 2006-12-01 to 2010-06-29
# - SUB:
#   missing from 1998-01-28 to 2001-02-27
# - SUN:
#   missing from 1996-01-02 to 1997-12-29
# - SVU:
#   missing on 1996-07-23
#   missing on 1997-06-06
#   missing on 1997-07-28
# - SYMC:
#   missing from 2003-03-31 to 2003-09-08
# - TA:
#   missing from 1996-01-02 to 1999-07-20
# - TCOMA:
#   missing from 1996-01-02 to 1997-12-29
# - TDM:
#   not downloaded from 1996-01-02 to 1997-08-26
# - TEK:
#   missing from 1996-01-02 to 1997-12-29
# - TEN:
#   missing from 1996-01-02 to 1999-10-29
# - THY:
#   missing from 1996-01-02 to 1996-10-08
# - TIN:
#   missing from 1996-01-02 to 1997-12-29
# - TMC:
#   missing from 1996-01-02 to 1997-12-29
# - TMC.A:
#   not downloaded from 1996-01-02 to 2000-06-09
# - TMK:
#   missing from 1996-01-02 to 2003-09-08
# - TNB:
#   missing from 1996-01-02 to 1997-12-29
# - TOS:
#   missing from 1999-09-20 to 2001-09-10
# - TOY:
#   missing from 1996-01-02 to 1997-12-29
# - TRB:
#   missing from 1996-01-02 to 1997-12-29
# - TRW:
#   missing from 1996-01-02 to 2002-12-09
# - TWX:
#   missing from 1996-01-02 to 1997-12-29
# - TX:
#   missing from 1996-01-02 to 1997-12-29
# - TXU:
#   missing from 1996-01-02 to 1997-12-29
# - UAWGQ:
#   not downloaded from 1996-01-02 to 2002-05-14
# - UCC:
#   missing from 1996-01-02 to 1999-04-28
# - UCL:
#   missing from 1996-01-02 to 2003-09-08
# - UCM:
#   missing from 1996-01-02 to 1997-12-29
# - UK:
#   missing from 1996-01-02 to 2001-01-31
# - UMG:
#   missing from 1996-01-02 to 2000-06-13
# - UPC:
#   missing from 1998-10-01 to 2004-06-28
# - UPR:
#   missing from 1996-10-16 to 1997-12-29
# - USBC:
#   missing from 1996-01-02 to 1997-08-01
# - USH:
#   not downloaded from 1996-01-02 to 1997-06-16
# - USHC:
#   not downloaded from 1996-01-02 to 1996-07-18
# - USS:
#   missing from 1996-01-02 to 1997-12-29
# - UST:
#   missing from 1996-01-02 to 1997-12-29
# - USW:
#   missing from 1996-01-02 to 1997-12-29
# - VAT:
#   not downloaded from 1996-01-02 to 1996-08-28
# - VO:
#   missing from 1996-01-02 to 2000-12-08
# - VRTS:
#   missing from 2000-04-03 to 2005-06-30
# - WAI:
#   missing from 1996-01-02 to 1998-08-06
# - WAMUQ:
#   missing from 1997-07-02 to 1997-12-29
# - WB:
#   missing from 1996-01-02 to 1997-12-29
# - WCOEQ:
#   not downloaded from 1996-04-01 to 2002-05-14
# - WLA:
#   missing from 1996-01-02 to 1997-12-29
# - WLL:
#   missing from 1996-01-02 to 1997-12-29
#   missing from 2001-04-18 to 2002-02-07
# - WLP:
#   missing from 1999-06-09 to 2004-11-26
# - WMX:
#   missing from 1996-01-02 to 1997-12-29
# - WNDXQ:
#   missing from 1996-01-02 to 1997-12-29
# - WWY:
#   missing from 1996-01-02 to 1997-12-29
# - WYE:
#   missing from 1996-01-02 to 1997-12-29
# DataFrame summary:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 2705 entries, 1996-01-02 to 2026-01-14
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   available       2705 non-null   int64
#  1   missing         2705 non-null   int64
#  2   not_downloaded  2705 non-null   int64
#  3   total           2705 non-null   int64
#  4   coverage_pct    2705 non-null   float64
# dtypes: float64(1), int64(4)
# memory usage: 126.8 KB
# None
#           available       missing  not_downloaded         total  coverage_pct
# count 2705.00000000 2705.00000000   2705.00000000 2705.00000000 2705.00000000
# mean   453.07652495   37.75748614      5.91534196  496.74935305   91.10260949
# std     71.16359382   61.36355224      6.35115227    5.16624733   13.80100530
# min    228.00000000    0.00000000      1.00000000  487.00000000   46.81724846
# 25%    446.00000000    7.00000000      2.00000000  494.00000000   90.10101010
# 50%    482.00000000   12.00000000      4.00000000  497.00000000   96.98189135
# 75%    489.00000000   41.00000000      8.00000000  499.00000000   98.39034205
# max    503.00000000  232.00000000     28.00000000  507.00000000   99.80158730
#             available  missing  not_downloaded  total  coverage_pct
# 1996-01-02        229      231              27    487   47.02258727
# 1996-01-03        229      231              27    487   47.02258727
# 2025-12-22        502        0               1    503   99.80119284
# 2026-01-14        502        0               1    503   99.80119284

# %%
plots.plot_missing_data_reasons("EODHD", filename="20-eodhd-missing-data-reasons.png")

# %%
import os, eodhd, pandas as pd, plots

api_key: str = os.getenv("EODHD_API_KEY")
client: eodhd.APIClient = eodhd.APIClient(api_key)
ticker: str = "BUD_old"
api_symbol: str = f"{ticker}.US"
kwargs: dict = {
    "symbol": api_symbol,
    "period": "d",
    "order": "a",
}
raw_data: list = client.get_eod_historical_stock_market_data(**kwargs)
frame: pd.DataFrame = pd.DataFrame(raw_data)
plots.summarize_df(frame)
# Out:
# DataFrame summary:
# <class 'pandas.DataFrame'>
# RangeIndex: 2738 entries, 0 to 2737
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            2738 non-null   str
#  1   open            2738 non-null   float64
#  2   high            2738 non-null   float64
#  3   low             2738 non-null   float64
#  4   close           2738 non-null   float64
#  5   adjusted_close  2738 non-null   float64
#  6   volume          2738 non-null   int64
# dtypes: float64(5), int64(1), str(1)
# memory usage: 149.9 KB
# None
#                open          high           low         close  adjusted_close  \
# count 2738.00000000 2738.00000000 2738.00000000 2738.00000000   2738.00000000
# mean    44.90321512   45.33625676   44.49535829   44.90413879     44.90413879
# std      9.06532739    9.08338739    9.04698015    9.06036439      9.06036439
# min     21.56300000   21.71900000   21.46900000   21.71900000     21.71900000
# 25%     40.50000000   41.00000000   40.00000000   40.50500000     40.50500000
# 50%     47.03000000   47.48000000   46.70500000   47.08500000     47.08500000
# 75%     50.81750000   51.19000000   50.50000000   50.81000000     50.81000000
# max     68.90000000   69.26000000   68.54000000   68.58000000     68.58000000
#
#                  volume
# count     2738.00000000
# mean   3162178.46712929
# std    3488193.52612240
# min     418600.00000000
# 25%    1838075.00000000
# 50%    2440650.00000000
# 75%    3334275.00000000
# max   85285104.00000000
#             date        open        high         low       close  \
# 0     1997-12-31 22.09400000 22.12500000 21.87500000 22.00000000
# 1     1998-01-02 21.68800000 22.18800000 21.50000000 22.18800000
# 2736  2008-11-14 68.00000000 69.26000000 67.60000000 68.50000000
# 2737  2008-11-17 68.90000000 68.90000000 68.54000000 68.58000000
#
#       adjusted_close    volume
# 0        22.00000000    916200
# 1        22.18800000    940600
# 2736     68.50000000  22554000
# 2737     68.58000000   8090400
